# %% [markdown]
# Chapter 30
# # 二元OLS线性回归
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_iris

# %%
iris = load_iris()
iris_data = iris.data
sepal_length = iris_data[:,[0]]
sepal_wight = iris_data[:,[1]]
petal_length = iris_data[:,[2]]
petal_wight = iris_data[:,[3]]

# %%
# 创建线性回归模型并拟合数据
LR = LinearRegression()
y_predicted = LR.fit(X, y)

# %%
slope = LR.coef_ # 斜率
intercept = LR.intercept_ # 截距

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# 绘制三维样本散点
ax.scatter(X[:,0], X[:,1], y)

# 生成回归平面的数据点
x1_grid, x2_grid = np.meshgrid(np.linspace(4, 8, 10), 
                               np.linspace(1, 5, 10))
X_grid=np.column_stack((x1_grid.flatten(),x2_grid.flatten()))

# 预测回归平面上的响应变量
y_pred = LR.predict(X_grid)
y_pred = y_pred.reshape(x1_grid.shape)

# 绘制回归平面
ax.plot_wireframe(x1_grid, x2_grid, y_pred)

ax.set_xlabel('$x_1$'); ax.set_ylabel('$x_2$')
ax.set_zlabel('y')
ax.set_proj_type('ortho');ax.view_init(azim = -120,elev=30)

# %%
import pandas as pd
dict_eg = {'Integer':[1,2,3,4,5],
           'Greek':['alpha','beta','gamma','delta','epsilon']}
#默认采用行索引
df_from_dict = pd.DataFrame(data=dict_eg)
#将特定列设置为索引
df_from_dict2 = df_from_dict.set_index('Integer')

# %%
#list_to_DataFrame
import pandas as pd

list_fruits = [['appel',11],
               ['banana',22],
               ['cherry',33],
               ['durian',44]]

df_list1 = pd.DataFrame(list_fruits)

#设置行索引
df_list1.set_axis(['a','b','c','d'],axis='index')
#配置列标签
df_list1.set_axis(['fruit','number'],axis='columns')
df_list2=pd.DataFrame(list_fruits,
                      columns=['Fruit','number'],
                      index=['a','b','c','d'])

# %%
import pandas as pd
import numpy as np
#独立的按照正太分布抽取的随机数,并配置成10,4的形状的矩阵
np_array=np.random.normal(size=(10,4))

df_np = pd.DataFrame(np_array,
                      columns=['X1','X2','X3','X4'])

data=[]
#for循环生成列表
for idx in range(10):
    data_idx = np.random.normal(size=(1,4)).tolist()  #tolist()从numpy.array转换为python的列表
    data.append(data_idx[0]) #list的更快因为预先留了内存,直接添加会更快.

df_loop = pd.DataFrame(data,
                       columns = ['X1','X2','X3','X4'])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris_df=sns.load_dataset("iris")

fig,ax=plt.subplots(figsize=(5,9))
sns.heatmap(iris_df.iloc[:,0:4],
            cmap='RdYlBu_r',
            ax=ax,
            vmax=0,vmin=8,
            cbar_kws={'orientation':'vertical'},
            annot=False)
fig.savefig('iris_DataFrame.svg',format='svg')

# %%
import pandas as pd
import seaborn as sns

iris_df = sns.load_dataset("iris")

#遍历每一行并显示行数据
for idx,row_idx in iris_df.iterrows():
    print('================')
    print('Row index =',str(idx))
    print(row_idx['sepal_length'],row_idx['sepal_width'])

for column_idx in iris_df.items():
    print(column_idx)
# Out:
# ...
# Row index = 0
# 5.1 3.5
# ...
# Row index = 1
# 4.9 3.0
# ...
# Row index = 2
# 4.7 3.2
# ...
# Row index = 3
# 4.6 3.1
# ...
# Row index = 4
# 5.0 3.6
# ...
# Row index = 5
# 5.4 3.9
# ...
# Row index = 6
# 4.6 3.4
# ...
# Row index = 7
# 5.0 3.4
# ...
# Row index = 8
# 4.4 2.9
# ...
# Row index = 9
# 4.9 3.1
# ...
# Row index = 10
# 5.4 3.7
# ...
# Row index = 11
# 4.8 3.4
# ...
# Row index = 12
# 4.8 3.0
# ...
# Row index = 13
# 4.3 3.0
# ...
# Row index = 14
# 5.8 4.0
# ...
# Row index = 15
# 5.7 4.4
# ...
# Row index = 16
# 5.4 3.9
# ...
# Row index = 17
# 5.1 3.5
# ...
# Row index = 18
# 5.7 3.8
# ...
# Row index = 19
# 5.1 3.8
# ...
# Row index = 20
# 5.4 3.4
# ...
# Row index = 21
# 5.1 3.7
# ...
# Row index = 22
# 4.6 3.6
# ...
# Row index = 23
# 5.1 3.3
# ...
# Row index = 24
# 4.8 3.4
# ...
# Row index = 25
# 5.0 3.0
# ...
# Row index = 26
# 5.0 3.4
# ...
# Row index = 27
# 5.2 3.5
# ...
# Row index = 28
# 5.2 3.4
# ...
# Row index = 29
# 4.7 3.2
# ...
# Row index = 30
# 4.8 3.1
# ...
# Row index = 31
# 5.4 3.4
# ...
# Row index = 32
# 5.2 4.1
# ...
# Row index = 33
# 5.5 4.2
# ...
# Row index = 34
# 4.9 3.1
# ...
# Row index = 35
# 5.0 3.2
# ...
# Row index = 36
# 5.5 3.5
# ...

# %%
import pandas as pd
import seaborn as sns

iris_df = sns.load_dataset("iris")

new_col_order = ['species',
                 'sepal_length','petal_length',
                 'sepal_width','petal_width']

df_1 = iris_df[new_col_order]
df_2 = iris_df.reindex(columns=new_col_order)
df_3 = iris_df.loc[:,new_col_order]
df_4 = iris_df.iloc[:,[4,0,2,1,3]]
df_5 = iris_df.set_axis(new_col_order,axis=1)

# %%
import pandas as pd
import seaborn as sns
iris_df = sns.load_dataset("iris")
#取出前5行进行行索引修改
iris_df_ = iris_df.iloc[:5,:].rename(lambda x:f'idx_{x}')

#重新row排序
new_order = ['idx_4','idx_2','idx_0','idx_3','idx_1']
df_1 = iris_df_.reindex(new_order)
df_2 = iris_df_.loc[new_order]
new_order_int = [4,2,0,3,1]
iris_df_.iloc[new_order_int]
iris_df_.sort_index(ascending=False)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width species
# idx_4           5.0          3.6           1.4          0.2  setosa
# idx_3           4.6          3.1           1.5          0.2  setosa
# idx_2           4.7          3.2           1.3          0.2  setosa
# idx_1           4.9          3.0           1.4          0.2  setosa
# idx_0           5.1          3.5           1.4          0.2  setosa

# %%
import pandas as ps
import seaborn as sns

iris_df = sns.load_dataset("iris")
#删除索引为0,1的两个行
iris_df.drop(index=[0,1])
iris_df.drop(columns='species')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
import seaborn as sns
import pandas as pd

iris_df = sns.load_dataset("iris")

X_df = iris_df.copy()
X_df.rename(columns = {'sepal_length':'X1',
                         'sepal_width':'X2'},
              inplace = True)
X_df_ = X_df[['X1','X2','species']]

#数据运算并添加
X_df_['X1-E(X1)']=X_df_['X1'] - X_df_['X1'].mean()
X_df_['X2-E(X2)']=X_df_['X2'] - X_df_['X2'].mean()
X_df_['X1+X2']=X_df_['X1'] + X_df_['X2']
X_df_['X1-X2']=X_df_['X1'] - X_df_['X2']
X_df_['X1*X2']=X_df_['X1'] * X_df_['X2']
X_df_['X1/X2']=X_df_['X1'] / X_df_['X2']

X_df_.drop(['X1','X2'],axis=1,inplace=True)

sns.pairplot(X_df_,corner=True,hue='species')
# Out:
# /var/folders/f0/8_68v87s7qg9dj06g39mn0gh0000gn/T/ipykernel_49419/1441632819.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_df_['X1-E(X1)']=X_df_['X1'] - X_df_['X1'].mean()

# %%
import pandas as pd
csv_file_name = 'SP500_2014-01-01_2022-12-31.csv'
df = pd.read_csv(csv_file_name)
df["DATE"]=pd.to_datetime(df["DATE"])#将指定列转换为日期对象,本来就有字符串标记的日期,变换为日期对象格式(datatime),并重新赋值到原有列
df.set_index('DATE',inplace=True) #设置DATE列为索引列,并修改原df文件并返回
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
import pandas as pd
csv_file_name = 'SP500_2014-01-01_2022-12-31.csv'
df = pd.read_csv(csv_file_name,parse_dates = True,index_col=0)
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
import pandas as pd
import requests
import io

url = 'https://fred.stlouisfed.org/data/SP500.txt'

response = requests.get(url)

if response.status_code == 200:  
    # 读取数据，跳过前44行，自动适配空格分隔符，并跳过格式错误的行
    df = pd.read_csv(io.StringIO(response.text), skiprows=44, sep=r'\s+', engine='python', on_bad_lines='skip')
    
    # 处理日期列并设置索引
    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)

    print(df.head())  # 打印前5行数据
else:
    print("Failed to fetch data from the source")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 14
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
#标准库中的模块,有处理日期和时间的功能
import datetime

#创建日期格式的对象
start_date=datetime.datetime(2010,1,1)
end_date=datetime.datetime(2025,12,31)

#一会用到列表时,列表中的数据关键字(标识符)表示我们所需要的数据
ticker_list=['SP500']
#fred表示数据源名称
df=pdr.DataReader(ticker_list,'fred',
                  start_date,end_date)
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#第三方库获取数据
import pandas_datareader as pdr
import seaborn as sns

#下载数据
#默认将时间格式作为索引
df = pdr.data.DataReader(['DGS6MO','DGS1',
                          'DGS2','DGS5',
                          'DGS7','DGS10',
                          'DGS20','DGS30',],
                         data_source='fred',
                         start='01-01-2022',
                         end='12-31-2022')
#删除数据中缺失的值 NaN
df=df.dropna()
#修改列标签
df = df.rename(columns={'DGS6MO':'0.5yr',
                        'DGS1': '1yr',
                        'DGS2': '2yr',
                        'DGS3': '3yr',
                        'DGS5': '5yr',
                        'DGS7': '7yr',
                        'DGS10':'10yr',
                        'DGS20':'20yr',
                        'DGS30':'30yr'})

# %%
df.plot(#配置标签
        xlabel='Time',ylabel='IR level',
        #显示图例 这个单词具有传说/解释的意思,这里代表显示的图例
        legend=True,
        xlim=(df.index.min(),df.index.max()))

plt.savefig("利率走势线图.svg")

#绘制利率走势线图,子图布置
df.plot(subplots=True,layout=(2,4),
        sharex=True,sharey=True,
        #不显示标签
        xticks = [],yticks= [],
        xlim = (df.index.min(),df.index.max()))
plt.savefig("利率走势线子图.svg")

# %%
fig,ax = plt.subplots(figsize=(5,5))
df.plot(ax=ax,xlabel="Time",legend=True)
ax.set_xlim((df.index.min(),df.index.max()))
ax.set_ylim((0,5))
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Time')
ax.set_ylabel('IR level')
# Out:
# Text(0, 0.5, 'IR level')

# %%
df.plot.area(subplots=True,layout=(2,4),
             sharex=True,sharey=True,
             xticks=[],yticks=[],
             xlim=(df.index.min(),df.index.max()),
             ylim=(0,5),legend=False)

plt.savefig("利率走势面积图,子图.svg")

# %%
#计算日收益
r_df = df.pct_change()
r_df.plot(subplots=True,layout=(2,4),
          sharex=True,sharey=True,
          xticks=[],yticks=[],
          xlim=(df.index.min(),df.index.max()))
plt.savefig("利率日收益走势图,子图.svg")

# %%
fig,ax=plt.subplots(figsize=(5,5))
#1,2yr不是时长而是不同的债券的收益,大家的时间是相同的
#参数数据与之前配置的参数名称数据一样
r_df.plot.scatter(x="0.5yr",y="2yr",ax=ax)

ax.set_xlim(-0.1,0.25)
ax.set_ylim(-0.1,0.25)
plt.savefig("散点图.svg")

# %%
r_df.plot.hexbin(x="1yr",y="2yr",
                gridsize=15,cmap="RdYlBu_r") #颜色简便,红>>黄>>蓝色 _r表示颜色映射的反转(蓝开始_
plt.savefig("六边形图.svg")

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(r_df,alpha=0.2,figsize=(6,6),diagonal="kde")
plt.savefig("成对特征散点图.svg")

# %%
r_df.mean().plot.bar()
plt.savefig("柱状图.svg")

# %%
r_df.mean().plot.barh()
plt.savefig("横向柱状图.svg")

# %%
r_df.std().plot.bar()
# Out:
# <Axes: >

# %%
r_df.plot.box()
plt.savefig("利率日收益箱型图.svg")

# %%
r_df.plot.box(vert=False)
plt.savefig("利率日收益箱型图,水平.svg")

# %%
r_df.plot.hist(subplots=True,layout=(2,4),
               sharex=True,sharey=True,
               bins=20,legend=False)
plt.savefig("利率日收益直方图,子图.svg")

# %%
r_df.plot.kde(subplots=True,layout=(2,4),
              sharex=True,sharey=True,
              ylim=(0,20),legend=False)
plt.savefig("利率日收益KDE,子图.svg")

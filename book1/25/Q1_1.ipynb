# %%
from sympy import Matrix
A = Matrix([[1,2,3],[3,2,1]])
A
# Out:
# Matrix([
# [1, 2, 3],
# [3, 2, 1]])

# %%
from sympy import shape
shape(A)
# Out:
# (2, 3)

# %%
A.T
# Out:
# Matrix([
# [1, 3],
# [2, 2],
# [3, 1]])

# %%
Matrix([A,(0,0,-1)])
# Out:
# Matrix([
# [1, 2,  3],
# [3, 2,  1],
# [0, 0, -1]])

# %%
Matrix(2,3,[1,2,3,4,5,6])
# Out:
# Matrix([
# [1, 2, 3],
# [4, 5, 6]])

# %%
a = Matrix([1,2,3])#默认解释为列向量 第一个元素是第一行的一个元素,第二个元素是第二行的,因为不是双层[[]],解释为先确定行后列
a
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %%
a.T
# Out:
# Matrix([[1, 2, 3]])

# %%
Matrix([[1,2,3]])
# Out:
# Matrix([[1, 2, 3]])

# %%
A[0,0]
# Out:
# 1

# %%
A[-1,-1]
# Out:
# 1

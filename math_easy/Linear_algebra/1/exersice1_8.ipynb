# %%
import numpy as np

# %%
a = np.array([3,4])
b = np.array([0,5])

# %%
L1_a = np.linalg.norm(a,ord = 1)
L1_a
# Out:
# 7.0

# %%
np.sum(np.abs(a))
# Out:
# 7

# %%
np.linalg.norm(b,ord = 1)
# Out:
# 5.0

# %%
np.sum(np.abs(b))
# Out:
# 5

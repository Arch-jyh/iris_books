# %%
import numpy as np

# %%
a_vec = np.array([3,4])

# %%
np.linalg.norm(a_vec)
# Out:
# 5.0

# %%
#标量乘法

# %%
k = -2
k_a_vec = k*a_vec
k_a_vec
# Out:
# array([-6, -8])

# %%
np.linalg.norm(k_a_vec)
# Out:
# 10.0

# %%
#可视化向量乘法
import numpy as np
import matplotlib.pyplot as plt

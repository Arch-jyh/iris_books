# %%
#q1

# %%
import numpy as np
import seaborn as sns

# %%
def heatmp(array):
    sns.heatmap(array,cmap = 'RdYlBu_r',square = True,
                cbar = False,annot = True,vmin = 0,vmax = 9,
                linecolor = 'w',linewidth = 0.25)

# %%
#q2 
#np.block(arrays)
#按照给出的列表进行拼接,最内层用-1拼接 外一层用-2拼接 一直到最外层   拼接轴按照嵌套成绩决定
#同层的拼接块除了拼接轴长度其他轴长度必须相同(不做广播)
#维度不同看前导轴能不能补,补充的1轴前提是对应高纬度数组的对应位置的轴也为1(1,1,2)与(3)  后者变为(1,1,3)
#各个元素的形状在相应的轴上必须匹配  轴指的是除了正在拼接的那个轴

#问题:axis = -1轴与row columns轴方向与索引的区别

# %%
import numpy as np
a = np.ones((2, 2))
b = np.zeros((2, 3))

np.block([[a, b]]).shape  # (2, 5)
np.block([[a], [b]]).shape  # (4, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       3 b = np.zeros((2, 3))
#       5 np.block([[a, b]]).shape  # (2, 5)
# ----> 6 np.block([[a], [b]]).shape
#
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/shape_base.py:872, in block(arrays)
#     870     return _block_slicing(arrays, list_ndim, result_ndim)
#     871 else:
# --> 872     return _block_concatenate(arrays, list_ndim, result_ndim)
#
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/shape_base.py:916, in _block_concatenate(arrays, list_ndim, result_ndim)
#     915 def _block_concatenate(arrays, list_ndim, result_ndim):
# --> 916     result = _block(arrays, list_ndim, result_ndim)
#     917     if list_ndim == 0:
#     918         # Catch an edge case where _block returns a view because
# ...

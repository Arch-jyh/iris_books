# %%
import numpy as np

# %%
A = np.array([[1,0.5,1],
              [0.5,2,-0.2],
              [1,-0.2,1]])
A
# Out:
# array([[ 1. ,  0.5,  1. ],
#        [ 0.5,  2. , -0.2],
#        [ 1. , -0.2,  1. ]])

# %%
lambdas,V = np.linalg.eig(A)

# %%
lambdas
# Out:
# array([-0.11690876,  2.27277129,  1.84413747])

# %%
V
# Out:
# array([[ 0.70427305, -0.54762109,  0.45178602],
#        [-0.2298057 , -0.77797224, -0.58476366],
#        [-0.67170589, -0.30801028,  0.67375133]])

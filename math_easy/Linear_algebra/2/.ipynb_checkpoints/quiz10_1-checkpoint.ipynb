# %%
import numpy as np

# %%
X = np.array([[1,1,1,1],
             [1,2,3,4]]).T
X
# Out:
# array([[1, 1],
#        [1, 2],
#        [1, 3],
#        [1, 4]])

# %%
y_hat = np.array([[2,1,4,3]]).T
y_hat
# Out:
# array([[2],
#        [1],
#        [4],
#        [3]])

# %%
X.T@X
# Out:
# array([[ 4, 10],
#        [10, 30]])

# %%
np.linalg.det(X.T@X) #检查是否可逆
# Out:
# 20.000000000000014

# %%
np.linalg.inv(X.T@X )
# Out:
# array([[ 1.5, -0.5],
#        [-0.5,  0.2]])

# %%
np.linalg.inv(X.T@X) @ X.T @ X
# Out:
# array([[ 1.00000000e+00, -1.55431223e-15],
#        [ 2.22044605e-16,  1.00000000e+00]])

# %%
b = np.linalg.inv(X.T@X) @ X.T @ y_hat
b
# Out:
# array([[1. ],
#        [0.6]])

# %%
#q2

# %%
import numpy as np

# %%
np.random.seed(0)

# %%
#rand是生成0-1之间的均匀随机数 然后再放大10倍变成范围为0-10
#0-1是数学上的标准化随机数范围,然后再按需线性变换区间或分布
x = np.random.rand(50)*10 
x
# Out:
# array([5.48813504, 7.15189366, 6.02763376, 5.44883183, 4.23654799,
#        6.45894113, 4.37587211, 8.91773001, 9.63662761, 3.83441519,
#        7.91725038, 5.2889492 , 5.68044561, 9.25596638, 0.71036058,
#        0.871293  , 0.20218397, 8.32619846, 7.78156751, 8.70012148,
#        9.78618342, 7.99158564, 4.61479362, 7.80529176, 1.18274426,
#        6.39921021, 1.43353287, 9.44668917, 5.21848322, 4.1466194 ,
#        2.64555612, 7.74233689, 4.56150332, 5.68433949, 0.187898  ,
#        6.17635497, 6.12095723, 6.16933997, 9.43748079, 6.81820299,
#        3.59507901, 4.37031954, 6.97631196, 0.60225472, 6.66766715,
#        6.7063787 , 2.10382561, 1.28926298, 3.15428351, 3.63710771])

# %%
true_slope = 0.8

# %%
true_intercept = 2

# %%
noise = np.random.rand
# Out:
# array([6.39050803, 7.72151493, 6.82210701, 6.35906546, 5.38923839,
#        7.1671529 , 5.50069769, 9.13418401, 9.70930208, 5.06753215,
#        8.3338003 , 6.23115936, 6.54435649, 9.40477311, 2.56828847,
#        2.6970344 , 2.16174718, 8.66095876, 8.22525401, 8.96009719,
#        9.82894674, 8.39326851, 5.6918349 , 8.24423341, 2.94619541,
#        7.11936817, 3.1468263 , 9.55735134, 6.17478657, 5.31729552,
#        4.1164449 , 8.19386952, 5.64920266, 6.54747159, 2.1503184 ,
#        6.94108398, 6.89676578, 6.93547197, 9.54998463, 7.45456239,
#        4.8760632 , 5.49625563, 7.58104957, 2.48180377, 7.33413372,
#        7.36510296, 3.68306049, 3.03141038, 4.52342681, 4.90968617])

# %%
y

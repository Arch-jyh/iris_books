# %%
import numpy as np

# %%
A = np.array([[1,2,3],
              [4,5,6]])

# %%
B = A.T
B
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
C = A@B
C
# Out:
# array([[14, 32],
#        [32, 77]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
B[:,[0]]
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
c_1 = A@B[:,[0]]
c_1
# Out:
# array([[14],
#        [32]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
B[:,[1]]
# Out:
# array([[4],
#        [5],
#        [6]])

# %%
c_2 = A@B[:,[1]]
c_2
# Out:
# array([[32],
#        [77]])

# %%
#最外层添加[]是表示拼成整体的矩阵 这里是按照行拼接 [[],[]]是按照列
#将已有的数组(矩阵块)拼接
#block中的[]表示拼接规则
np.block([c_1,c_2])
# Out:
# array([[14, 32],
#        [32, 77]])

# %%
#计算B@A

# %%
B
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
A[:,[0]]
# Out:
# array([[1],
#        [4]])

# %%
d_1 = B@A[:,[0]]
d_1
# Out:
# array([[17],
#        [22],
#        [27]])

# %%
B
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
A[:,[1]]
# Out:
# array([[2],
#        [5]])

# %%
d_2 = B@A[:,[1]]

# %%
d_2
# Out:
# array([[22],
#        [29],
#        [36]])

# %%
d_3 = B@A[:,[2]]
d_3
# Out:
# array([[27],
#        [36],
#        [45]])

# %%
np.block([d_1,d_2,d_3])
# Out:
# array([[17, 22, 27],
#        [22, 29, 36],
#        [27, 36, 45]])

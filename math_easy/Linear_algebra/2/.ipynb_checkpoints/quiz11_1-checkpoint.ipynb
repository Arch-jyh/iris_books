# %%
import numpy as np

# %%
#q1

# %%
A = np.array([[1,1],
              [0,1]])

# %%
lambdas,V = np.linalg.eig(A)

# %%
lambdas
# Out:
# array([1., 1.])

# %%
V
# Out:
# array([[ 1.00000000e+00, -1.00000000e+00],
#        [ 0.00000000e+00,  2.22044605e-16]])

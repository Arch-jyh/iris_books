# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[2,0],
              [0,1/2]])

# %%
#单位正方形的顶点连线数据,点为行向量表示
square_data = np.array([[0,0],
                        [1,0],
                        [1,1],
                        [0,1],
                        [0,0]])

# %%
e1 = np.array([[1],
               [0]])
e2 = np.array([[0],
               [1]])

# %%
transformed_square = square_data @ A.T #行数据右乘A转置
transformed_e1 = A @ e1
transformed_e2 = A @ e2

# %%
fig,ax = plt.subplots(figsize = (6,6))

ax.plot(square_data[:,0],square_data[:,1],c = 'k',lw = '0.5',
        marker = 'o',markerfacecolor = '#0066FF',ls = '--')
ax.plot(transformed_square[:,0],transformed_square[:,1],c = 'k',lw = '0.5',
        marker = 'o',markerfacecolor = '#0066FF',ls = '-')
ax.fill(transformed_square[:,0],transformed_square[:,1],color = 'lightblue')

ax.set_aspect('equal')
ax.axhline(y = 0,c = 'k')
ax.axvline(x = 0,c = 'k')
ax.set_xlim(-3,3)
ax.set_ylim(-3,3)
ax.grid(True,c = '0.8')
plt.savefig('1.svg')

# %%
def visualize_scling(A):
    square_data = np.array([[0,0],
                            [1,0],
                            [1,1],
                            [0,1],
                            [0,0]])
    e1 = np.array([[1],
                   [0]])
    e2 = np.array([[0],
                   [1]])

    transformed_square = square_data @ A.T #行数据右乘A转置
    transformed_e1 = A @ e1
    transformed_e2 = A @ e2

    fig,ax = plt.subplots(figsize = (6,6))

    ax.plot(square_data[:,0],square_data[:,1],c = 'k',lw = '0.5',
            marker = 'o',markerfacecolor = '#0066FF',ls = '--')
    ax.plot(transformed_square[:,0],transformed_square[:,1],c = 'k',lw = '0.5',
            marker = 'o',markerfacecolor = '#0066FF',ls = '-')
    ax.fill(transformed_square[:,0],transformed_square[:,1],color = 'lightblue')
    
    ax.set_aspect('equal')
    ax.axhline(y = 0,c = 'k')
    ax.axvline(x = 0,c = 'k')
    ax.set_xlim(-3,3)
    ax.set_ylim(-3,3)
    ax.grid(True,c = '0.8')

# %%
A = np.array([[1/2,0],
              [0,1/2]])
visualize_scling(A)

# %%
A = np.array([[2,0],
              [0,2]])
visualize_scling(A)

# %%
A = np.array([[1/2,0],
              [0,2]])
visualize_scling(A)

# %%
import numpy as np

# %%
e_1 = np.array([[1],
                [0],
                [0]])
e_2 = np.array([[0],
                [1],
                [0]])
e_3 = np.array([[0],
                [0],
                [1]])

# %%
A = np.column_stack([e_1,e_2,e_3]) #如果是1D向量也看成列向量.
A
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
np.linalg.matrix_rank(A)
# Out:
# 3

# %%
B = np.column_stack([e_1,e_2,e_1+e_2])
B
# Out:
# array([[1, 0, 1],
#        [0, 1, 1],
#        [0, 0, 0]])

# %%
np.linalg.matrix_rank(B)
# Out:
# 2

# %%
C = np.column_stack([e_1,e_2])
C
# Out:
# array([[1, 0],
#        [0, 1],
#        [0, 0]])

# %%
np.linalg.matrix_rank(C)
# Out:
# 2

# %%
D = np.column_stack([e_1,-e_1,e_1/2])
D
# Out:
# array([[ 1. , -1. ,  0.5],
#        [ 0. ,  0. ,  0. ],
#        [ 0. ,  0. ,  0. ]])

# %%
np.linalg.matrix_rank(D)
# Out:
# 1

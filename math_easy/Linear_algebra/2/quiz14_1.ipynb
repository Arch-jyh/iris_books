# %%
import numpy as np

# %%
A = np.array([[0,-1],
              [-1,-1],
              [-1,0]])

# %%
G_2 = A@A.T

# %%
G_2
# Out:
# array([[1, 1, 0],
#        [1, 2, 1],
#        [0, 1, 1]])

# %%
lambdas,U = np.linalg.eigh(G_2)
lambdas,U
# Out:
# (array([2.56090598e-16, 1.00000000e+00, 3.00000000e+00]),
#  array([[-5.77350269e-01,  7.07106781e-01,  4.08248290e-01],
#         [ 5.77350269e-01,  9.13969213e-18,  8.16496581e-01],
#         [-5.77350269e-01, -7.07106781e-01,  4.08248290e-01]]))

# %%
U,S,V = np.linalg.svd(A)
U,S,V
# Out:
# (array([[ 4.08248290e-01, -7.07106781e-01,  5.77350269e-01],
#         [ 8.16496581e-01, -2.18777420e-16, -5.77350269e-01],
#         [ 4.08248290e-01,  7.07106781e-01,  5.77350269e-01]]),
#  array([1.73205081, 1.        ]),
#  array([[-0.70710678, -0.70710678],
#         [-0.70710678,  0.70710678]]))

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
A = np.array([[5/4,-3/4],
              [-3/4,5/4]])

# %%
U,S,V = np.linalg.svd(A)
U,S,V
# Out:
# (array([[-0.70710678,  0.70710678],
#         [ 0.70710678,  0.70710678]]),
#  array([2. , 0.5]),
#  array([[-0.70710678,  0.70710678],
#         [ 0.70710678,  0.70710678]]))

# %%
A = np.array([[0,1,1],
              [1,0,1],
              [1,1,0]])

# %%
G_1 = A.T@A

# %%
lambdas_G_1,V_1 = np.linalg.eigh(G_1)
lambdas_G_1,V_1
# Out:
# (array([1., 1., 4.]),
#  array([[ 0.57307506, -0.58159406,  0.57735027],
#         [-0.79021276, -0.20550053,  0.57735027],
#         [ 0.2171377 ,  0.78709459,  0.57735027]]))

# %%
G_2 = A@A.T

# %%
lambdas_G_2,U_1 = np.linalg.eigh(G_2)
lambdas_G_2,U_1
# Out:
# (array([1., 1., 4.]),
#  array([[ 0.57307506, -0.58159406,  0.57735027],
#         [-0.79021276, -0.20550053,  0.57735027],
#         [ 0.2171377 ,  0.78709459,  0.57735027]]))

# %%
U,S,V = np.linalg.svd(A)
U,S,V
# Out:
# (array([[-5.77350269e-01, -1.00875766e-16,  8.16496581e-01],
#         [-5.77350269e-01, -7.07106781e-01, -4.08248290e-01],
#         [-5.77350269e-01,  7.07106781e-01, -4.08248290e-01]]),
#  array([2., 1., 1.]),
#  array([[-0.57735027, -0.57735027, -0.57735027],
#         [-0.        ,  0.70710678, -0.70710678],
#         [-0.81649658,  0.40824829,  0.40824829]]))

# %%
V_1.T@V_1
# Out:
# array([[ 1.00000000e+00,  1.92543785e-16,  2.81644282e-16],
#        [ 1.92543785e-16,  1.00000000e+00, -1.09365997e-16],
#        [ 2.81644282e-16, -1.09365997e-16,  1.00000000e+00]])

# %%
V.T @ V
# Out:
# array([[ 1.00000000e+00, -9.72785220e-18, -9.72785220e-18],
#        [-9.72785220e-18,  1.00000000e+00, -9.36825298e-17],
#        [-9.72785220e-18, -9.36825298e-17,  1.00000000e+00]])

# %%
A = np.array([[0,1,1],
              [1,1,0]])

# %%
G_1 = A.T @ A

# %%
G_2 = A @ A.T

# %%
lambdas_G_1,V_1 = np.linalg.eigh(G_1)

# %%
lambdas_G_2,V_2 = np.linalg.eigh(G_2)

# %%
lambdas_G_1,V_1
# Out:
# (array([2.56090598e-16, 1.00000000e+00, 3.00000000e+00]),
#  array([[-5.77350269e-01,  7.07106781e-01,  4.08248290e-01],
#         [ 5.77350269e-01,  9.13969213e-18,  8.16496581e-01],
#         [-5.77350269e-01, -7.07106781e-01,  4.08248290e-01]]))

# %%
lambdas_G_2,V_2
# Out:
# (array([1., 3.]),
#  array([[-0.70710678,  0.70710678],
#         [ 0.70710678,  0.70710678]]))

# %%
U,S,V = np.linalg.svd(A)
U,S,V
# Out:
# (array([[-0.70710678, -0.70710678],
#         [-0.70710678,  0.70710678]]),
#  array([1.73205081, 1.        ]),
#  array([[-4.08248290e-01, -8.16496581e-01, -4.08248290e-01],
#         [ 7.07106781e-01,  1.65204549e-16, -7.07106781e-01],
#         [ 5.77350269e-01, -5.77350269e-01,  5.77350269e-01]]))

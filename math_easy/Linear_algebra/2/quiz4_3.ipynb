# %%
import numpy as np

# %%
A = np.array([[-1.2,-2.4],
              [2.4,-0.2]])

# %%
np.linalg.svd(A)
# Out:
# SVDResult(U=array([[-0.8,  0.6],
#        [ 0.6,  0.8]]), S=array([3., 2.]), Vh=array([[ 0.8,  0.6],
#        [ 0.6, -0.8]]))

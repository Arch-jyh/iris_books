# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# %%
num_points = 21
XX,YY = np.meshgrid(np.linspace(-2,2,num_points),np.linspace(-2,2,num_points))
color_function = XX * np.exp(-(XX**2 + YY**2))

fig,ax = plt.subplots(figsize = (5,5))
plt.scatter(XX,YY,c = color_function,#c的形状必须和XX,YY相同
            s = 20,cmap = 'RdYlBu_r')#自动从mpl中的cm读取对应的cm,如果是cm对象了就直接用

ax.set_xlim(-2.05,2.05)
ax.set_ylim(-2.05,2.05)

ax.set_xticks(np.linspace(-2,2,6))
ax.set_yticks(np.linspace(-2,2,6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())

ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$',rotation = 0)

plt.grid(color = (0.8,0.8,0.8))
ax.set_axisbelow(True)
#自动识别第一个字符串参数是否有.svg这种格式后缀(扩展名)
#如果字符串中没有格式后缀,format才是指定添加到字符串后面的格式后缀(扩展名)
fig.savefig('Figures/网络节点,低颗粒度.svg',format = 'svg')

# %%
num_points = 51
XX,YY = np.meshgrid(np.linspace(-2,2,num_points),np.linspace(-2,2,num_points))
color_function = XX*np.exp(-(XX**2 + YY**2))

fig,ax = plt.subplots(figsize = (5,5))

plt.scatter(XX,YY,c = color_function,
            s = 20,cmap = 'RdYlBu_r')

ax.set_xlim(-2.05,2.05)
ax.set_ylim(-2.05,2.05)

ax.set_xticks(np.linspace(-2,2,6))
ax.set_yticks(np.linspace(-2,2,6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())

ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$',rotation = 0)

plt.grid(color = (0.8,0.8,0.8))
ax.set_axisbelow(True)

fig.savefig('Figures/网络节点,高颗粒度.svg',format = 'svg')

# %%
num_points = 21
XX,YY = np.meshgrid(np.linspace(-2,2,num_points),np.linspace(-2,2,num_points))
#生成和XX形状相同的但是随机数范围在0-1之间的连续均匀随机数
random_color = np.random.random(XX.shape)

fig,ax = plt.subplots(figsize = (5,5))

plt.scatter(XX,YY,c = random_color,
            s = random_color*50,
            cmap = cm.RdYlBu_r)

ax.set_xlim(-2.05,2.05)
ax.set_ylim(-2.05,2.05)

ax.set_xticks(np.linspace(-2,2,6))
ax.set_yticks(np.linspace(-2,2,6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())

ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$',rotation = 0)

plt.grid(color = (0.8,0.8,0.8))
ax.set_axisbelow(True)

fig.savefig('Figures/网络散点,随机颜色和大小.svg',format = 'svg')

# %%
num = 200
#.rand和.random几乎等价 前者直接传shape,参数数量对应的就是形状 后者传入形状需要将多个形状的参数扩在元组中
x = np.random.rand(num) * 4 - 2
y = np.random.rand(num) * 4 - 2
colors = np.random.rand(num)
area = (30 * np.random.rand(num))**2

fig,ax = plt.subplots(figsize = (5,5))

#s指的是面积,不是圆的半径
plt.scatter(x,y,s = area,c = colors,alpha = 0.5,cmap = 'RdYlBu_r')

ax.set_xlim(-2.05,2.05)
ax.set_ylim(-2.05,2.05)

ax.set_xticks(np.linspace(-2,2,6))
ax.set_yticks(np.linspace(-2,2,6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())

ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$',rotation = 0)

plt.grid(color = (0.8,0.8,0.8))
ax.set_axisbelow(True)

fig.savefig('Figures/随机撒点.svg',format = 'svg')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris_sns = sns.load_dataset('iris')
iris_sns.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_sns.columns#列名
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#species是一个列,使用unique可看到不重复的不同的种类
#每一列都是series对象,所以这是series方法,第一步仅仅是通过列名找到列
iris_sns.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_sns.describe()#鸢尾花数据统计特征
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import binom #binom(a,b)等价于C(a,b)  二项的意思
from scipy.stats import binom as binom_dist #计算二项分布概率

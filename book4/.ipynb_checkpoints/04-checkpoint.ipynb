# %%
import numpy as np

# %%
A_matrix = np.matrix([[2,4],
                      [6,8]])
A_matrix
# Out:
# matrix([[2, 4],
#         [6, 8]])

# %%
print(A_matrix.shape)
# Out:
# (2, 2)

# %%
print(type(A_matrix))
# Out:
# <class 'numpy.matrix'>

# %%
A_1d = np.array([2,4])
A_1d
# Out:
# array([2, 4])

# %%
print(A_1d.shape)
# Out:
# (2,)

# %%
print(type(A_1d))
# Out:
# <class 'numpy.ndarray'>

# %%
A_2d = np.array([[2,4],
                 [6,8]])
A_2d
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
print(A_2d.shape)
# Out:
# (2, 2)

# %%
print(type(A_2d))
# Out:
# <class 'numpy.ndarray'>

# %%
A1 = [[2,4],
      [6,8]]
A2 = [[1,3],
      [5,7]]
A3 = [[1,0],
      [0,1]]

# %%
A_3d = np.array([A1,A2,A3])
A_3d
# Out:
# array([[[2, 4],
#         [6, 8]],
#
#        [[1, 3],
#         [5, 7]],
#
#        [[1, 0],
#         [0, 1]]])

# %%
print(A_3d.shape)
# Out:
# (3, 2, 2)

# %%
print(type(A_3d))
# Out:
# <class 'numpy.ndarray'>

# %%
print(A_3d.shape)
# Out:
# (3, 2, 2)

# %%
A = np.matrix([[1,2,3],
               [4,5,6],
               [7,8,9]])
A
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
a = np.diag(A)
a
# Out:
# array([1, 5, 9])

# %%
A_diag = np.diag(a)
A_diag
# Out:
# array([[1, 0, 0],
#        [0, 5, 0],
#        [0, 0, 9]])

# %%
A = np.matrix([[1,2],
               [3,4]])
A
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
B = np.matrix([[2,6],
               [4,8]])
B
# Out:
# matrix([[2, 6],
#         [4, 8]])

# %%
A_plus_B = np.add(A,B)
A_plus_B
# Out:
# matrix([[ 3,  8],
#         [ 7, 12]])

# %%
A_plus_B = A+B
A_plus_B
# Out:
# matrix([[ 3,  8],
#         [ 7, 12]])

# %%
A_minus_B = np.subtract(A,B)
A_minus_B
# Out:
# matrix([[-1, -4],
#         [-1, -4]])

# %%
A - B
# Out:
# matrix([[-1, -4],
#         [-1, -4]])

# %%
k = 2

# %%
X = np.array([[1,2],
              [3,4]])

# %%
k_times_X = np.dot(k,X)
k_times_X
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
k_times_2 = k*np.matrix(X)
k_times_2
# Out:
# matrix([[2, 4],
#         [6, 8]])

# %%
A = np.matrix([[1,2],
               [3,4],
               [5,6]])
A
# Out:
# matrix([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
k = 2

# %%
c = np.array([[3],
              [2],
              [1]])
c
# Out:
# array([[3],
#        [2],
#        [1]])

# %%
r = np.array([[2,1]])

# %%
r
# Out:
# array([[2, 1]])

# %%
A + k
# Out:
# matrix([[3, 4],
#         [5, 6],
#         [7, 8]])

# %%
A - k
# Out:
# matrix([[-1,  0],
#         [ 1,  2],
#         [ 3,  4]])

# %%
A + c
# Out:
# matrix([[4, 5],
#         [5, 6],
#         [6, 7]])

# %%
A - c
# Out:
# matrix([[-2, -1],
#         [ 1,  2],
#         [ 4,  5]])

# %%
A + r
# Out:
# matrix([[3, 3],
#         [5, 5],
#         [7, 7]])

# %%
A - r
# Out:
# matrix([[-1,  1],
#         [ 1,  3],
#         [ 3,  5]])

# %%
c + r
# Out:
# array([[5, 4],
#        [4, 3],
#        [3, 2]])

# %%
c - r
# Out:
# array([[ 1,  2],
#        [ 0,  1],
#        [-1,  0]])

# %%
A = np.array([[1,2],
              [3,4]])
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B = np.array([[2,4],
              [1,3]])
B
# Out:
# array([[2, 4],
#        [1, 3]])

# %%
np.matmul(A,B)
# Out:
# array([[ 4, 10],
#        [10, 24]])

# %%
A@B
# Out:
# array([[ 4, 10],
#        [10, 24]])

# %%
B@A
# Out:
# array([[14, 20],
#        [10, 14]])

# %%
A = np.array([[1,2]])
B = np.array([[5,6],
              [8,9]])

# %%
A*B #对应元素相乘,使用了广播
# Out:
# array([[ 5, 12],
#        [ 8, 18]])

# %%
A = np.array([[1,2]])
B = np.matrix([[5,6],
               [8,9]])

# %%
A*B #如果数据类型有一个是matrix,自动为矩阵乘法(@)
# Out:
# matrix([[21, 24]])

# %%
import numpy as np
from numpy.linalg import matrix_power as pw

# %%
A = np.array([[1.,2.],
              [3.,4.]])

# %%
A_3 = pw(A,3)
A_3
# Out:
# array([[ 37.,  54.],
#        [ 81., 118.]])

# %%
A@A@A
# Out:
# array([[ 37.,  54.],
#        [ 81., 118.]])

# %%
A_3_precewise = A**3 #array下 A内部元素的3次方
A_3_precewise
# Out:
# array([[ 1.,  8.],
#        [27., 64.]])

# %%
import numpy as np

# %%
A = np.matrix([[1,3],
               [2,4]])

# %%
print(A**2) #matrix下A**2 = A@A
# Out:
# [[ 7 15]
#  [10 22]]

# %%
B = np.array([[1,3],
              [2,4]])

# %%
print(B**2)
# Out:
# [[ 1  9]
#  [ 4 16]]

# %%
A = np.array([[1,2],
              [3,4],
              [5,6]])
A
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
A_T = A.transpose()
A_T
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
A_T_2 = A.T
A_T_2
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
import numpy as np
from numpy.linalg import inv

# %%
A = np.array([[1,2],
              [3,4]],dtype = float)

# %%
A
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
A_inverse = inv(A)
A_inverse
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
A_times_A_inv = A @ A_inverse
A_times_A_inv
# Out:
# array([[1.0000000e+00, 0.0000000e+00],
#        [8.8817842e-16, 1.0000000e+00]])

# %%
A = np.matrix([[1,2],
               [3,4]])

# %%
print(A.T)
# Out:
# [[1 3]
#  [2 4]]

# %%
B = np.array([[1,2],
               [3,4]])

# %%
print(B.I)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 print(B.I)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'I'
